# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayushiii/Practicals/blob/main/practical_3-TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/datasets/Churn.csv')
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
x = pd.get_dummies(df.drop(['Churn','Customer ID'], axis=1))
y = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
x_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 510                0       1            19.85              1            0
# 1247               0      45           105.15              1            0
# 361                0       5            20.20              0            1
# 2347               0      71            95.75              1            0
# 2825               0      63            19.25              0            1
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 510            1            0              1               0
# 1247           0            1              0               1
# 361            1            0              0               1
# 2347           0            1              0               1
# 2825           0            1              1               0
#
#       Phone Service_No  ...  Total Charges_995.35  Total Charges_996.45  \
# 510                  0  ...                     0                     0
# ...

# %%
y_train.head()
# Out:
# 510     0
# 1247    0
# 361     0
# 2347    0
# 2825    0
# Name: Churn, dtype: int64

# %%
pip install tensorflow

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(x_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model.fit(x_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 177/177 [==============================] - 2s 8ms/step - loss: 0.5122 - accuracy: 0.7553
# Epoch 2/20
# 177/177 [==============================] - 2s 9ms/step - loss: 0.4917 - accuracy: 0.7688
# Epoch 3/20
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4826 - accuracy: 0.7766
# Epoch 4/20
# 177/177 [==============================] - 2s 10ms/step - loss: 0.4791 - accuracy: 0.7732
# Epoch 5/20
# 177/177 [==============================] - 2s 10ms/step - loss: 0.4781 - accuracy: 0.7744
# Epoch 6/20
# 177/177 [==============================] - 2s 9ms/step - loss: 0.4732 - accuracy: 0.7771
# Epoch 7/20
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4720 - accuracy: 0.7778
# Epoch 8/20
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4700 - accuracy: 0.7753
# Epoch 9/20
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4716 - accuracy: 0.7768
# Epoch 10/20
# ...

# %%
y_hat = model.predict(x_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 [==============================] - 0s 3ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.808374733853797

# %%
model.save('tfmodel')

# %%
del model

# %%
model = load_model('tfmodel')
